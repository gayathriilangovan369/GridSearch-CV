# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children', 'sex_male', 'smoker_yes']]
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[['charges']]
dependent
# Out:
#           charges
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# ...           ...
# 1333  10600.54830
# 1334   2205.98080
# 1335   1629.83350
# 1336   2007.94500
# 1337  29141.36030
#
# [1338 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(independent,dependent,test_size=0.3,random_state=0)

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeRegressor
param_grid={'criterion':['squared_error', 'friedman_mse', 'absolute_error', 'poisson'],
            'splitter':['best', 'random'],'max_features':['int', 'float','sqrt', 'log2']}
grid=GridSearchCV(DecisionTreeRegressor(),param_grid,refit=True,verbose=3,n_jobs=-1)
grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# C:\Users\gayut\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 80 fits failed out of a total of 160.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 27 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\gayut\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#     ~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\gayut\anaconda3\Lib\site-packages\sklearn\base.py", line 1358, in wrapper
#     estimator._validate_params()
#     ~~~~~~~~~~~~~~~~~~~~~~~~~~^^
# ...

# %%
result=grid.cv_results_

# %%
result
# Out:
# {'mean_fit_time': array([0.00359073, 0.00311584, 0.00211902, 0.00122056, 0.01113915,
#         0.00882726, 0.00650907, 0.00526972, 0.00138679, 0.00098543,
#         0.00095534, 0.001087  , 0.00502253, 0.00615282, 0.00665736,
#         0.00580831, 0.00116773, 0.00189557, 0.00105848, 0.00106945,
#         0.02064314, 0.01819768, 0.01879454, 0.014077  , 0.00094714,
#         0.00100784, 0.00096459, 0.00093894, 0.0070796 , 0.00568929,
#         0.00831714, 0.00524468]),
#  'std_fit_time': array([4.69422136e-04, 1.26159437e-03, 1.32016765e-03, 1.80432156e-04,
#         3.98725815e-03, 3.35305494e-03, 9.37494195e-04, 8.45880134e-04,
#         5.09245400e-04, 1.87462414e-04, 2.71683929e-04, 8.42945602e-05,
#         7.21364463e-04, 7.34005482e-04, 6.08114860e-04, 1.72409910e-03,
#         3.52818899e-05, 1.07318120e-03, 2.86822470e-04, 2.22731377e-04,
#         2.94109159e-03, 9.32852128e-04, 3.24983179e-03, 1.17278458e-03,
# ...

# %%
table=pd.DataFrame.from_dict(result)

# %%
table

# %%
table.columns
table=table.sort_values(by='rank_test_score')
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 28       0.007080      0.001009         0.003008        0.000408
# 6        0.006509      0.000937         0.003590        0.000581
# 4        0.011139      0.003987         0.006944        0.002370
# 12       0.005023      0.000721         0.003309        0.000310
# 14       0.006657      0.000608         0.003550        0.000341
# 30       0.008317      0.001831         0.004022        0.001613
# 22       0.018795      0.003250         0.003378        0.000624
# 7        0.005270      0.000846         0.003256        0.000508
# 31       0.005245      0.001643         0.003556        0.000274
# 29       0.005689      0.001246         0.002946        0.000504
# 5        0.008827      0.003353         0.003038        0.000349
# 23       0.014077      0.001173         0.003076        0.000667
# 13       0.006153      0.000734         0.003139        0.000319
# ...

# %%
dttable=table[['param_criterion','param_splitter','std_test_score','rank_test_score']]
dttable.columns=[['Criterion','Splitter','STD Score','Rank']]
dttable
# Out:
#          Criterion Splitter STD Score Rank
# 28         poisson     best  0.038195    1
# 6    squared_error     best  0.035900    2
# 4    squared_error     best  0.035290    3
# 12    friedman_mse     best  0.094306    4
# 14    friedman_mse     best  0.056259    5
# 30         poisson     best  0.078096    6
# 22  absolute_error     best  0.092043    7
# 7    squared_error   random  0.082338    8
# 31         poisson   random  0.059727    9
# 29         poisson   random  0.089865   10
# 5    squared_error   random  0.056246   11
# 23  absolute_error   random  0.107270   12
# 13    friedman_mse   random  0.088084   13
# 21  absolute_error   random  0.087499   14
# 15    friedman_mse   random  0.127230   15
# 20  absolute_error     best  0.150716   16
# 10    friedman_mse     best       NaN   17
# 1    squared_error   random       NaN   17
# 2    squared_error     best       NaN   17
# 27         poisson   random       NaN   17
# 26         poisson     best       NaN   17
# ...

# %%
y_pred=grid.predict(x_test)
from sklearn.metrics import r2_score
r2score=r2_score(y_test,y_pred)
r2score
# Out:
# 0.695568130331707

# %%
Age = float(input("Please enter your age: "))
BMI = float(input("Please enter your BMI: "))
Children = float(input("Please enter number of children: "))

Gender = input("Please enter your gender: ").lower()
if Gender == "male":
    gender = 1
else:
    gender = 0

Smoker = input("Do you smoke? (yes/no): ").lower()
if Smoker == "yes":
    smoker = 1
else:
    smoker = 0

charger_prediction = grid.predict([[Age, BMI, Children, gender, smoker]])

print("Estimated Charge is:", charger_prediction[0])
